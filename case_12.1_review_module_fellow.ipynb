# %% [markdown]
# # Review module

# %% [markdown]
# **Instructions**
#
# In order to complete this review module, we recommend you follow these instructions:
#
# 1. Complete the functions provided to you in this notebook, but do **not** change the name of the function or the name(s) of the argument(s). If you do that, the autograder will fail and you will not receive any points.
# 2. Run all the function-definition cells before you run the testing cells. The functions must exist before they are graded!
# 3. Read the function docstrings carefully. They contain additional information about how the code should look (a [docstring](https://www.datacamp.com/community/tutorials/docstrings-python) is the stuff that comes between the triple quotes).
# 4. Some functions may require several outputs (the docstrings tell you which ones). Make sure they are returned in the right order.
# 5. Remove from each function the code `raise NotImplementedError()` and replace it with your implementation.

# %% [markdown]
# For this review module, we will be using the same database we introduced in the main lecture. This database consists of three tables: `agent` (a list of the call center agents), `customer` (a list of the customers and their demographic data), and `call` (all the calls that the agents made and whether they resulted in a purchase or not).
#
# Run the cells below to load the SQLite database and see the names of the columns of each table:

# %%
# %%capture
# !pip install ipython-sql sqlalchemy pandas
import sqlalchemy
sqlalchemy.create_engine("sqlite:///call_center_database.db")
# %load_ext sql
# %sql sqlite:///call_center_database.db

# %%
# %%sql
# select * from agent limit 0
# Out:
#  * sqlite:///call_center_database.db
# Done.
# []

# %%
# %%sql
# select * from customer
# Out:
#  * sqlite:///call_center_database.db
# Done.
# [('0', 'David Melton', 'Unemployed', 'DMelton@zoho.com', 'Morris, Winters and Ramirez', '409-093-0748', '16'),
#  ('1', 'Michael Gonzalez', 'Student', 'Gonzalez_Michael@yahoo.com', 'Hernandez and Sons', '231-845-0673', '19'),
#  ('2', 'Amanda Wilson', 'Student', 'Amanda.Wilson75@verizon.com', 'Mooney, West and Hansen', '844-276-4552', '18'),
#  ('3', 'Robert Thomas', 'Engineer, structural', 'RThomas@xfinity.com', 'Johnson-Gordon', '410-404-8000', '25'),
#  ('4', 'Eddie Hall', 'Surgeon', 'EddieHall@outlook.com', 'Dawson LLC', '872-287-2196', '30'),
#  ('5', 'Charles Cruz DDS', 'Unemployed', 'CharlesDDS55@hotmail.com', 'Mitchell and Sons', '744-564-0382', '16'),
#  ('6', 'Maria Johnson', 'Engineer, aeronautical', 'MJohnson@aol.com', 'Gibbs-Avery', '448-258-9852', '22'),
#  ('7', 'Michael Vaughn', 'Librarian, public', 'MichaelVaughn@zoho.com', 'Rice LLC', '275-669-5217', '30'),
#  ('8', 'Emily Anderson DDS', 'Solicitor', 'Emily_DDS@yahoo.com', 'Little and Sons', '334-290-7258', '28'),
#  ('9', 'Travis Jensen', 'Unemployed', 'Travis.Jensen@hotmail.com', 'Edwards-Collins', '106-848-8870', '13'),
#  ('10', 'Ryan Banks', 'Student', 'Ryan_Banks35@gmail.com', 'Mitchell, Dean and Rivera', '465-548-1441', '21'),
#  ('11', 'Brandon Alexander', 'Chemical engineer', 'Alexander_Brandon@att.com', 'Robbins Ltd', '305-319-8515', '29'),
#  ('12', 'Valerie Moore', 'Unemployed', 'Moore_Valerie@verizon.com', 'Choi and Sons', '288-680-8457', '16'),
#  ('13', 'Tina Cox', 'Unemployed', 'Tina_Cox@protonmail.com', 'Giles, Harris and Sparks', '535-922-1854', '16'),
#  ('14', 'Michelle Reyes', 'Engineer, drilling', 'Michelle.Reyes@aol.com', 'Stewart, Dawson and Lane', '280-280-1661', '31'),
#  ('15', 'Grace Pearson', 'Unemployed', 'Grace_P@yandex.com', 'Taylor-Walker', '973-809-0260', '14'),
#  ('16', 'Lauren Hill', 'Counsellor', 'Hill_Lauren73@aol.com', 'Parsons, Nelson and Walker', '175-283-1682', '27'),
#  ('17', 'Kelsey Perkins', 'Nurse', 'Kelsey_P80@att.com', 'Stephenson, Mccoy and Olson', '925-021-2855', '25'),
#  ('18', 'Zachary Howe', 'Unemployed', 'Howe.Zachary@xfinity.com', 'Mullins, Dawson and Cross', '556-773-8367', '0'),
#  ('19', 'Elizabeth Harris', 'Unemployed', 'Elizabeth_Harris36@hotmail.com', 'Grant, Bowman and Sawyer', '177-551-8499', '11'),
#  ('20', 'Angela Myers', 'Unemployed', 'Angela.Myers79@xfinity.com', 'Valentine-Jenkins', '507-312-2781', '4'),
#  ('21', 'Bridget Turner', 'Unemployed', 'Turner_Bridget66@verizon.com', 'Henderson LLC', '578-620-4478', '10'),
#  ('22', 'Sean Martinez', 'Engineer, manufacturing systems', 'SeanMartinez@outlook.com', 'Jones Ltd', '280-193-6840', '27'),
#  ('23', 'Laura Walton', 'Unemployed', 'Walton.Laura@xfinity.com', 'Harris Group', '332-989-5650', '15'),
#  ('24', 'Samantha Travis', 'Solicitor', 'STravis59@outlook.com', 'Miller LLC', '778-558-6695', '28'),
#  ('25', 'Pamela Estrada', 'Chemical engineer', 'Pamela_E@protonmail.com', 'Kline PLC', '801-604-6888', '23'),
#  ('26', 'Gary Avila', 'Engineer, civil (contracting)', 'Gary.Avila@aol.com', 'Arnold, Powell and Smith', '683-963-6839', '25'),
#  ('27', 'Sean Trevino', 'Engineer, water', 'Trevino_Sean@gmail.com', 'Hogan-Warren', '349-209-0139', '32'),
#  ('28', 'Michael Smith', 'Chemical engineer', 'Michael.S@verizon.com', 'Gutierrez-Martin', '781-655-9073', '38'),
#  ('29', 'Arthur Gray', 'Chemical engineer', 'ArthurGray@zoho.com', 'Holt, Miller and Decker', '338-817-0407', '32'),
#  ('30', 'Ruben Rangel III', 'Solicitor', 'Ruben.I@gmail.com', 'Horne, Wilkerson and James', '178-691-5082', '37'),
#  ('31', 'Victoria Gibson', 'Engineer, control and instrumentation', 'Gibson.Victoria77@verizon.com', 'Perry, Castro and Johnston', '935-145-8444', '38'),
#  ('32', 'Vanessa Davis', 'Police officer', 'Davis.Vanessa11@xfinity.com', 'Medina LLC', '718-892-2262', '24'),
#  ('33', 'Grace Perez', 'Unemployed', 'Perez.Grace@zoho.com', 'Medina-Sanders', '509-876-3370', '8'),
#  ('34', 'Richard Tran', 'Architect', 'Richard.Tran@aol.com', 'Williams, Wallace and Johnson', '473-005-7571', '42'),
#  ('35', 'Danny Ellis', 'Police officer', 'Ellis_Danny@mail.com', 'Marshall, Rice and Francis', '354-571-2506', '26'),
#  ('36', 'Danielle Norman', 'Student', 'Danielle.Norman@outlook.com', 'Williams, Burnett and Lowe', '734-348-4379', '21'),
#  ('37', 'Christopher Blackburn', 'Unemployed', 'Blackburn_Christopher@protonmail.com', 'Rivers Inc', '331-141-8247', '8'),
#  ('38', 'Benjamin Harris', 'Banker', 'Harris.Benjamin@att.com', 'Johnson, Cook and Ferrell', '967-661-4148', '33'),
#  ('39', 'Mr. Ryan Benson MD', 'Unemployed', 'MD_Mr.@zoho.com', 'Jackson PLC', '504-062-0075', '14'),
#  ('40', 'Peter Nelson', 'Unemployed', 'PNelson@hotmail.com', 'Hayes, Reyes and Johnson', '613-808-4968', '7'),
#  ('41', 'Mariah Smith', 'Unemployed', 'Mariah_Smith44@verizon.com', 'Woods, Fields and Kelly', '661-632-3828', '7'),
#  ('42', 'Joseph Stewart', 'Unemployed', 'Joseph.S50@outlook.com', 'Buchanan-Bryan', '322-144-7056', '17'),
#  ('43', 'Melissa Hamilton', 'Engineer, structural', 'Hamilton.Melissa55@protonmail.com', 'Chan, Smith and Davis', '495-724-8706', '24'),
#  ('44', 'Amanda Castillo', 'Unemployed', 'AmandaCastillo@aol.com', 'Santos and Sons', '311-684-9511', '6'),
#  ('45', 'Tonya Reed', 'Dentist', 'Tonya_R@yandex.com', 'Davis, Buckley and Johnson', '567-766-1694', '38'),
#  ('46', 'Christopher Bishop', 'Student', 'Christopher.B@zoho.com', 'Moore-White', '107-315-1619', '18'),
#  ('47', 'Matthew Chapman', 'Doctor, general practice', 'MatthewChapman88@xfinity.com', 'Hoffman-Moore', '409-194-3924', '34'),
#  ('48', 'Lisa Smith', 'Unemployed', 'Lisa_Smith66@xfinity.com', 'Brock Group', '214-474-4007', '14'),
#  ('49', 'Barbara Preston', 'Unemployed', 'Barbara.P93@outlook.com', 'Singleton, Smith and Franklin', '893-920-4044', '17'),
#  ('50', 'Jonathan Meadows', 'Student', 'JMeadows@hotmail.com', 'Sanders, Lewis and Cross', '608-508-5084', '18'),
#  ('51', 'Nicholas Robertson', 'Chemical engineer', 'Robertson.Nicholas@protonmail.com', 'Hernandez, Collins and Mata', '168-928-0066', '26'),
#  ('52', 'Charles Coleman', 'Unemployed', 'Coleman.Charles77@verizon.com', 'Nelson-Guzman', '689-253-7418', '15'),
#  ('53', 'Christina Murphy', 'Unemployed', 'Christina.M72@gmail.com', 'Hutchinson, Lewis and Lambert', '811-430-2477', '8'),
#  ('54', 'Justin Anderson', 'Engineer, manufacturing systems', 'JustinAnderson@outlook.com', 'Turner Inc', '674-789-4341', '23'),
#  ('55', 'John Weiss', 'Student', 'JohnWeiss90@yahoo.com', 'Rodriguez, Lawson and Foster', '133-555-7593', '18'),
#  ('56', 'Dennis Johnson', 'Editor', 'Johnson.Dennis@yandex.com', 'Hawkins Ltd', '314-131-3013', '47'),
#  ('57', 'Martin Stephenson', 'Unemployed', 'MartinStephenson@mail.com', 'Lee, Richardson and Thompson', '113-035-1383', '17'),
#  ('58', 'William Mitchell', 'Editor', 'Mitchell_William55@zoho.com', 'Callahan Ltd', '350-001-7376', '33'),
#  ('59', 'Pamela Atkins', 'Student', 'Pamela_A@yahoo.com', 'Matthews LLC', '895-207-3772', '18'),
#  ('60', 'Alyssa Gill', 'Engineer, broadcasting (operations)', 'Gill.Alyssa@hotmail.com', 'Wise PLC', '497-572-6249', '27'),
#  ('61', 'Timothy Jensen', 'Engineer, production', 'Timothy_J@zoho.com', 'Powers, Shaw and Burgess', '240-457-7921', '39'),
#  ('62', 'Christopher Gilbert', 'Chemical engineer', 'Christopher_Gilbert@gmail.com', 'Miller, Hall and Wright', '447-555-1382', '26'),
#  ('63', 'John Cortez', 'Chemical engineer', 'JCortez37@att.com', 'Hernandez-Pierce', '434-864-5302', '23'),
#  ('64', 'Kevin Ferguson', 'Unemployed', 'KFerguson@att.com', 'Tanner, Martinez and Chapman', '462-849-1051', '11'),
#  ('65', 'Adam Jimenez', 'Unemployed', 'Jimenez.Adam47@outlook.com', 'Clark-Cook', '966-848-9733', '14'),
#  ('66', 'Joshua Olson', 'Unemployed', 'Joshua_Olson@yahoo.com', 'Molina and Sons', '889-887-7090', '4'),
#  ('67', 'Shelia Barnes', 'Engineer, production', 'Barnes_Shelia@outlook.com', 'Smith, Vega and Lin', '171-457-1855', '22'),
#  ('68', 'Timothy Munoz', 'Unemployed', 'Timothy_M68@aol.com', 'Robinson-Haley', '770-185-0597', '4'),
#  ('69', 'Sabrina James', 'Engineer, aeronautical', 'SJames@xfinity.com', 'Wilson-Hamilton', '244-463-2947', '28'),
#  ('70', 'Ryan Lynch', 'Student', 'Lynch_Ryan@protonmail.com', 'Chavez LLC', '690-970-8490', '21'),
#  ('71', 'Kelly Nguyen', 'Engineer, electronics', 'Kelly_Nguyen@protonmail.com', 'Walker, Hall and Boyd', '435-612-3991', '32'),
#  ('72', 'Patrick Ramos', 'Unemployed', 'Patrick.R@mail.com', 'Kramer-Reed', '869-914-4190', '6'),
#  ('73', 'Mrs. Kim Fields', 'Student', 'Mrs._Fields@outlook.com', 'Barry-Washington', '249-368-0795', '19'),
#  ('74', 'Kathleen Hicks', 'Engineer, water', 'Hicks_Kathleen@xfinity.com', 'Lucero Group', '903-526-1070', '31'),
#  ('75', 'Sylvia Knight', 'Student', 'Sylvia.Knight@verizon.com', 'Oconnor and Sons', '813-388-5104', '18'),
#  ('76', 'Darrell Joseph', 'Student', 'Joseph.Darrell@mail.com', 'Williams, Jacobson and Jimenez', '731-747-3885', '20'),
#  ('77', 'Tina Carey', 'Editor', 'Carey_Tina@yahoo.com', 'Barnett Ltd', '625-037-7653', '23'),
#  ('78', 'Todd Vang', 'Student', 'Todd_V97@hotmail.com', 'Anderson-Andrews', '363-591-2515', '19'),
#  ('79', 'Christopher Turner', 'Student', 'Christopher.Turner@verizon.com', 'Henry-Fowler', '950-752-9718', '20'),
#  ('80', 'Joseph Booth', 'Barista', 'Joseph_Booth40@outlook.com', 'Hansen Ltd', '527-395-9646', '30'),
#  ('81', 'Christopher Steele', 'Engineer, civil (contracting)', 'Christopher_Steele67@att.com', 'Baxter, Stanley and George', '786-607-4882', '29'),
#  ('82', 'Lauren Washington', 'Unemployed', 'Lauren_W@gmail.com', 'Douglas-Weber', '748-045-4163', '16'),
#  ('83', 'Judy Orozco', 'Student', 'Judy.Orozco@outlook.com', 'Jefferson-Cooper', '128-078-3609', '18'),
#  ('84', 'Danny Ford', 'Engineer, land', 'DFord60@aol.com', 'Murray LLC', '731-868-7220', '25'),
#  ('85', 'Gary Williams', 'Student', 'Williams_Gary@outlook.com', 'Meyers, Garcia and Cantu', '138-335-3561', '18'),
#  ('86', 'Ernest Fuller', 'Unemployed', 'Fuller.Ernest@yahoo.com', 'Moreno, Campbell and Chen', '537-839-4142', '17'),
#  ('87', 'Brooke Hamilton', 'Chemical engineer', 'Brooke_H72@comcast.net', 'Paul, Baker and Spencer', '332-077-0903', '23'),
#  ('88', 'Michael Martinez', 'Computer games developer', 'Michael_Martinez@verizon.com', 'Soto, Hamilton and Christensen', '169-232-0730', '28'),
#  ('89', 'Danielle Massey', 'Engineer, structural', 'DanielleMassey@verizon.com', 'Pitts-Gonzalez', '896-885-5785', '28'),
#  ('90', 'Selena Johnson', 'Unemployed', 'Johnson_Selena@xfinity.com', 'Woods-Fitzgerald', '951-497-4683', '17'),
#  ('91', 'Angela Gonzalez', 'Chemical engineer', 'Gonzalez_Angela54@outlook.com', 'Howard-Rogers', '279-913-3278', '29'),
#  ('92', 'Mark Clark', 'Orthoptist', 'Mark.C@verizon.com', 'Watson, Patterson and Murray', '452-360-9759', '22'),
#  ('93', 'Haley Gutierrez', 'Student', 'Gutierrez.Haley65@outlook.com', 'Walker-Obrien', '629-433-0625', '18'),
#  ('94', 'Mary Martin', 'Student', 'MaryMartin@gmail.com', 'Boyd Ltd', '829-096-0013', '21'),
#  ('95', 'Laura Romero', 'Student', 'Laura.Romero@aol.com', 'Robinson, Acosta and Randolph', '649-636-3972', '21'),
#  ('96', 'Kimberly Smith', 'Student', 'Kimberly_S@aol.com', 'Edwards, Wheeler and Combs', '542-606-6721', '20'),
#  ('97', 'Amanda Jackson', 'Computer games developer', 'Amanda.Jackson@hotmail.com', 'Parker-Hobbs', '535-805-1881', '23'),
#  ('98', 'Mr. Jeffery Payne', 'Student', 'Mr._Payne@yahoo.com', 'Mitchell-Montoya', '396-235-0610', '19'),
#  ('99', 'Kayla Evans', 'Solicitor', 'Evans.Kayla16@att.com', 'Webster-Melendez', '228-187-1377', '32'),
#  ('100', 'Meghan Douglas', 'Unemployed', 'Douglas_Meghan@outlook.com', 'Cruz Group', '360-912-8173', '12'),
#  ('101', 'Cindy Allen', 'Tour manager', 'Cindy.A72@yahoo.com', 'Bennett Ltd', '656-211-2904', '22'),
#  ('102', 'April Zamora', 'Student', 'April_Zamora@xfinity.com', 'Smith-Preston', '511-160-1129', '21'),
#  ('103', 'Jason Mason', 'Dentist', 'Jason.Mason61@zoho.com', 'Williamson-Armstrong', '720-379-3346', '29'),
#  ('104', 'Danny Douglas', 'Unemployed', 'Douglas_Danny@outlook.com', 'Velez and Sons', '279-805-8361', '16'),
#  ('105', 'Rachel Fischer', 'Student', 'Rachel.Fischer71@aol.com', 'Tucker Group', '660-232-6682', '21'),
#  ('106', 'Laura Burgess', 'Barista', 'Laura_Burgess@outlook.com', 'Miranda, Conrad and Oneal', '204-995-7304', '27'),
#  ('107', 'Michelle Armstrong', 'Risk analyst', 'MArmstrong@outlook.com', 'Bruce, Rodriguez and Arnold', '688-551-6065', '23'),
#  ('108', 'Cynthia Smith', 'Graphic designer', 'CSmith@att.com', 'Johnson, Potter and Maxwell', '877-501-3977', '33'),
#  ('109', 'Katherine Marshall', 'Unemployed', 'Marshall_Katherine@gmail.com', 'Manning PLC', '902-171-0373', '3'),
#  ('110', 'Chris Nichols', 'Student', 'Nichols_Chris@xfinity.com', 'Howell and Sons', '797-659-4210', '20'),
#  ('111', 'Lauren Vazquez', 'Chemical engineer', 'Lauren_V62@yahoo.com', 'Murray-Mcdowell', '807-867-2366', '34'),
#  ('112', 'Victoria Becker', 'Engineer, agricultural', 'VictoriaBecker@zoho.com', 'Cohen-Carter', '832-366-7449', '24'),
#  ('113', 'Jacob Adams', 'Unemployed', 'JacobAdams14@zoho.com', 'Snyder and Sons', '603-402-1557', '17'),
#  ('114', 'Scott Ballard', 'Air traffic controller', 'Ballard.Scott@gmail.com', 'Bailey PLC', '761-370-7203', '39'),
#  ('115', 'Dawn Garcia', 'Engineer, civil (consulting)', 'DawnGarcia57@zoho.com', 'Jones-Harris', '692-993-8894', '43'),
#  ('116', 'Scott Norris', 'Chemical engineer', 'Norris_Scott79@mail.com', 'Wiggins, Short and Sharp', '812-940-0883', '46'),
#  ('117', 'Joe Gray', 'Chemical engineer', 'Joe.Gray80@zoho.com', 'Johnson, Fuller and Harris', '548-691-4436', '26'),
#  ('118', 'John Williams', 'Graphic designer', 'Williams_John@verizon.com', 'Peterson-Cummings', '187-112-9606', '26'),
#  ('119', 'Claudia Mcdonald', 'Counsellor', 'Mcdonald_Claudia@outlook.com', 'Gonzales-Webb', '234-140-4659', '27'),
#  ('120', 'James Williams', 'Chemical engineer', 'James.W@yahoo.com', 'May PLC', '572-822-9141', '32'),
#  ('121', 'Kurt Phillips', 'Student', 'Kurt.P@zoho.com', 'Dawson-Smith', '414-209-5367', '18'),
#  ('122', 'Jill Garner', 'Orthoptist', 'Garner_Jill@zoho.com', 'Cook-Reed', '665-110-8604', '39'),
#  ('123', 'Jennifer Carr', 'Doctor, general practice', 'Jennifer_C48@xfinity.com', 'Franco-Walker', '280-534-7546', '27'),
#  ('124', 'Stacy Farley', 'Police officer', 'Stacy.F96@mail.com', 'Cobb, Page and Thompson', '406-773-2613', '24'),
#  ('125', 'Jasmine Crawford', 'Engineer, energy', 'Jasmine.Crawford@mail.com', 'Wilkinson, Fleming and Burch', '883-421-0101', '25'),
#  ('126', 'William Hess', 'IT consultant', 'William_H@att.com', 'Miller Group', '742-212-3289', '31'),
#  ('127', 'Catherine Lopez', 'Chemical engineer', 'Catherine.Lopez@yahoo.com', 'Hoover, Morris and Fisher', '444-982-5841', '26'),
#  ('128', 'Kelly Gutierrez', 'Student', 'KellyGutierrez@verizon.com', 'Williamson-Mclaughlin', '773-834-4123', '20'),
#  ('129', 'Joel Smith', 'Engineer, manufacturing', 'Joel.Smith@protonmail.com', 'Nelson, Rangel and Spencer', '834-749-7396', '30'),
#  ('130', 'Shelia Johns', 'Student', 'Shelia.J@aol.com', 'Martinez Inc', '989-809-0845', '20'),
#  ('131', 'Joshua Herrera', 'Architect', 'JHerrera76@mail.com', 'Sherman Inc', '524-813-0159', '36'),
#  ('132', 'Melanie Warren', 'Chemical engineer', 'Melanie_W@mail.com', 'Ortega, Silva and Krueger', '115-148-0418', '26'),
#  ('133', 'Jessica Miller', 'Unemployed', 'JMiller@att.com', 'Daniel, Murphy and Shah', '507-205-4322', '7'),
#  ('134', 'Joanna Li', 'Engineer, civil (contracting)', 'Li_Joanna@gmail.com', 'Cohen-Davis', '551-499-5266', '44'),
#  ('135', 'Samuel Anthony', 'Unemployed', 'Samuel.Anthony@zoho.com', 'Obrien Inc', '868-147-4182', '13'),
#  ('136', 'Rodney Lewis', 'Unemployed', 'Lewis_Rodney@zoho.com', 'Morgan-Dean', '146-248-7475', '16'),
#  ('137', 'Joseph Ross', 'Games developer', 'Ross.Joseph@yahoo.com', 'Gonzalez, Jones and Jackson', '650-892-8736', '32'),
#  ('138', 'Patricia Mendoza', 'Engineer, petroleum', 'Mendoza_Patricia@gmail.com', 'Price Ltd', '149-562-1588', '30'),
#  ('139', 'William Adams', 'Chemical engineer', 'Adams.William82@yandex.com', 'Salazar-Wall', '169-183-1879', '44'),
#  ('140', 'Robert Jones', 'Unemployed', 'RobertJones79@gmail.com', 'Fisher, Waller and Jennings', '238-062-7780', '14'),
#  ('141', 'Brittany Nixon', 'Engineer, electronics', 'Brittany_N@att.com', 'Johnson, Mclean and Chen', '697-782-8346', '35'),
#  ('142', 'Brittany Bailey', 'Architect', 'Bailey.Brittany@outlook.com', 'Stephens-Fleming', '905-439-5443', '40'),
#  ('143', 'Jessica Gardner', 'Unemployed', 'Jessica_G@mail.com', 'Allen-Mitchell', '462-566-5948', '16'),
#  ('144', 'Taylor Jones II', 'Unemployed', 'Taylor_I@yahoo.com', 'Carlson, Burnett and Torres', '274-204-7553', '3'),
#  ('145', 'Aaron Mcintyre', 'Unemployed', 'Mcintyre.Aaron@aol.com', 'Phillips-Scott', '911-295-7056', '14'),
#  ('146', 'Jason Hill', 'Student', 'Jason.Hill@gmail.com', 'Miller Ltd', '694-486-0988', '20'),
#  ('147', 'Nicole Parker', 'Doctor, general practice', 'Nicole.P@xfinity.com', 'Hawkins-Rojas', '772-939-2941', '24'),
#  ('148', 'Paul Brown', 'Student', 'PBrown@yandex.com', 'Frederick, Foley and Gillespie', '147-239-4580', '20'),
#  ('149', 'David Barrera', 'Engineer, civil (consulting)', 'David_Barrera@protonmail.com', 'Martinez-Thornton', '335-067-5536', '30'),
#  ('150', 'Parker Jones', 'Unemployed', 'Jones_Parker@hotmail.com', 'Ford PLC', '168-169-3087', '16'),
#  ('151', 'Daniel Shaw', 'Unemployed', 'Daniel.Shaw98@verizon.com', 'Walker, Smith and Freeman', '555-626-4152', '11'),
#  ('152', 'Holly Simmons', 'Chemical engineer', 'Holly_Simmons@protonmail.com', 'Oconnor, Montgomery and Green', '321-391-9214', '27'),
#  ('153', 'Victor Burns', 'Engineer, water', 'Burns.Victor54@yahoo.com', 'Blankenship, Riley and Davis', '750-167-9789', '42'),
#  ('154', 'Steven Mcfarland DDS', 'Unemployed', 'Steven_D69@verizon.com', 'Colon-Bell', '153-162-8331', '6'),
#  ('155', 'Morgan Rose', 'Student', 'Rose.Morgan@yandex.com', 'Cuevas Group', '492-544-8926', '20'),
#  ('156', 'Courtney Miller', 'Unemployed', 'Courtney.M@protonmail.com', 'Wood and Sons', '320-958-2535', '10'),
#  ('157', 'Maria Jarvis', 'Unemployed', 'Maria_J@verizon.com', 'Burke-Kim', '784-494-2528', '9'),
#  ('158', 'Ronald Hoffman', 'Engineer, drilling', 'Ronald_H@verizon.com', 'Villarreal-Spears', '895-068-5363', '44'),
#  ('159', 'Jason Daniels', 'Engineer, aeronautical', 'Jason.D@mail.com', 'Burton and Sons', '416-104-9515', '25'),
#  ('160', 'Joseph Jackson', 'Engineer, petroleum', 'Joseph.J@gmail.com', 'Bush-Swanson', '774-052-2265', '31'),
#  ('161', 'Paula Blevins', 'Chemical engineer', 'PBlevins@verizon.com', 'Wheeler-Welch', '334-845-4729', '28'),
#  ('162', 'Andrew Parks', 'Engineer, electrical', 'Parks.Andrew58@verizon.com', 'Watson, Blevins and Nguyen', '202-269-6160', '25'),
#  ('163', 'Philip Taylor', 'Engineer, manufacturing systems', 'Taylor_Philip@att.com', 'Bishop, Hatfield and West', '426-113-1284', '29'),
#  ('164', 'Justin Chang', 'Engineer, building services', 'Justin_C62@protonmail.com', 'Arias PLC', '398-425-0560', '38'),
#  ('165', 'Benjamin Howe', 'Dentist', 'Benjamin.Howe74@mail.com', 'Atkinson Ltd', '362-072-7439', '24'),
#  ('166', 'Derek Thomas', 'Solicitor', 'Thomas.Derek@mail.com', 'Davis, White and Lee', '512-153-6247', '41'),
#  ('167', 'Rita Holland', 'Unemployed', 'Rita.Holland@comcast.net', 'Lawson-Graham', '270-189-7614', '0'),
#  ('168', 'Lisa Hale', 'Student', 'Lisa_H@xfinity.com', 'Watson, Mitchell and Russell', '834-719-0286', '21'),
#  ('169', 'Brandy Wilson', 'Air traffic controller', 'Brandy.Wilson@yahoo.com', 'Cooper LLC', '982-322-4321', '39'),
#  ('170', 'Mrs. Maria Paul DVM', 'Student', 'Mrs._DVM@yandex.com', 'Sanchez-Bowman', '452-331-5798', '20'),
#  ('171', 'Jason Carson', 'Engineer, building services', 'Carson.Jason@comcast.net', 'Gutierrez LLC', '681-245-8366', '25'),
#  ('172', 'Shari Barnett', 'Unemployed', 'Barnett_Shari@gmail.com', 'Romero and Sons', '914-702-5632', '9'),
#  ('173', 'Justin Stephens', 'Student', 'Justin.Stephens@xfinity.com', 'Hudson and Sons', '572-196-8716', '20'),
#  ('174', 'Julie Dunn', 'Unemployed', 'Dunn.Julie@xfinity.com', 'Collier, Blankenship and Wolfe', '467-978-6513', '7'),
#  ('175', 'Sherri Nunez', 'Engineer, communications', 'Sherri.Nunez@att.com', 'Fisher Ltd', '846-549-9186', '33'),
#  ('176', 'Eric Arellano', 'Chemical engineer', 'Eric.A@outlook.com', 'Murray, Crane and Pena', '504-283-2079', '26'),
#  ('177', 'Amanda Rodriguez', 'Chemical engineer', 'Amanda_R@aol.com', 'Wood-Little', '475-720-2414', '44'),
#  ('178', 'Laura Roach', 'Engineer, civil (consulting)', 'Roach_Laura48@verizon.com', 'Miller Group', '847-285-9891', '23'),
#  ('179', 'William Davis', 'Chemical engineer', 'William_D@mail.com', 'Pruitt Ltd', '833-026-2499', '28'),
#  ('180', 'Nicholas Leonard', 'Engineer, petroleum', 'NLeonard14@protonmail.com', 'Hoffman, Gordon and Estrada', '335-350-2246', '37'),
#  ('181', 'Luis Archer', 'Engineer, structural', 'Luis.Archer@verizon.com', 'Brooks-Hines', '962-175-4522', '26'),
#  ('182', 'Lori Houston', 'Unemployed', 'Houston.Lori@hotmail.com', 'Campbell Inc', '451-303-8063', '12'),
#  ('183', 'Jaime Bradley', 'Student', 'Bradley.Jaime@mail.com', 'Bryant, Monroe and Hansen', '683-291-4579', '20'),
#  ('184', 'Billy Campbell', 'Unemployed', 'BCampbell@aol.com', 'Hubbard, Stein and Wheeler', '632-190-8720', '14'),
#  ('185', 'Bonnie Ochoa', 'Student', 'Bonnie.Ochoa@xfinity.com', 'Evans-Woods', '986-123-2986', '18'),
#  ('186', 'Raymond Rodriguez', 'Hotel manager', 'RRodriguez@protonmail.com', 'Ball-Clark', '266-766-1424', '30'),
#  ('187', 'Charlotte Clark', 'Engineer, control and instrumentation', 'Charlotte_C@verizon.com', 'Allen, Lin and Bradley', '564-723-1833', '40'),
#  ('188', 'Howard Reed', 'Engineer, manufacturing systems', 'Howard.R64@gmail.com', 'Williams-Vazquez', '150-369-6529', '27'),
#  ('189', 'Randy Adams', 'Actuary', 'Randy_Adams@outlook.com', 'Glover-Foley', '961-168-1796', '25'),
#  ('190', 'Monica Krueger', 'Electrical engineer', 'Monica.Krueger@outlook.com', 'Waters LLC', '375-129-5627', '49'),
#  ('191', 'Robin Garner', 'Student', 'Robin_G@protonmail.com', 'Barajas-Anderson', '769-746-0130', '20'),
#  ('192', 'James Martinez', 'Chemical engineer', 'James.Martinez@comcast.net', 'Johnston, Tanner and Cunningham', '523-550-8948', '27'),
#  ('193', 'Cassie Anderson', 'Unemployed', 'Anderson.Cassie@comcast.net', 'Blanchard and Sons', '907-877-5439', '11'),
#  ('194', 'Kimberly Brown', 'Engineer, biomedical', 'Kimberly_B@yahoo.com', 'Wilson-Davis', '503-427-8670', '27'),
#  ('195', 'Miguel Martin', 'Student', 'MMartin@xfinity.com', 'Klein, Smith and Barber', '509-518-2240', '19'),
#  ('196', 'Caleb Bowman', 'Engineer, biomedical', 'Caleb.Bowman42@verizon.com', 'Walker and Sons', '676-209-8409', '31'),
#  ('197', 'Richard Lowe', 'Engineer, structural', 'Richard_L@zoho.com', 'Mack, Brown and Powell', '933-684-0650', '30'),
#  ('198', 'John Moran', 'Unemployed', 'John.Moran@yahoo.com', 'Davis and Sons', '417-476-5566', '9'),
#  ('199', 'Shannon Dunlap', 'Dentist', 'Shannon.D@aol.com', 'Armstrong, Parker and Martin', '106-820-9910', '33'),
#  ('200', 'Mrs. Diane Johnson DDS', 'Unemployed', 'Mrs._DDS@xfinity.com', 'Garrison, Owens and Evans', '784-820-9063', '6'),
#  ('201', 'Nicholas Green', 'Air traffic controller', 'Nicholas.G@mail.com', 'Sullivan, King and Bailey', '798-149-3237', '30'),
#  ('202', 'Adrian Aguilar', 'Unemployed', 'Adrian_A@protonmail.com', 'Parker PLC', '504-961-9686', '1'),
#  ('203', 'Jeremiah Cole', 'Student', 'Jeremiah.C@outlook.com', 'Riddle, Benson and Crawford', '990-489-7137', '18'),
#  ('204', 'Michael Blackwell', 'Unemployed', 'Blackwell_Michael89@gmail.com', 'Wilson-Arellano', '385-507-1429', '-3'),
#  ('205', 'Laura Stone', 'Engineer, broadcasting (operations)', 'Laura_S@outlook.com', 'Holland-Thomas', '129-532-4957', '45'),
#  ('206', 'James Smith', 'Actor', 'JSmith@verizon.com', 'Garcia-Walters', '626-480-7007', '31'),
#  ('207', 'Angela Wood', 'Barista', 'Angela.W@hotmail.com', 'Davis and Sons', '271-796-6739', '22'),
#  ('208', 'Miguel Walker', 'Student', 'Miguel.Walker@yahoo.com', 'Walsh-Reid', '120-850-4008', '21'),
#  ('209', 'Ashley Price', 'Student', 'Ashley_P20@yahoo.com', 'Warren-Jones', '677-357-9980', '21'),
#  ('210', 'Martin Mata', 'Student', 'MartinMata@yahoo.com', 'Cabrera LLC', '549-303-6381', '20'),
#  ('211', 'Edwin Yang', 'Police officer', 'Yang_Edwin86@verizon.com', 'Mitchell, Thompson and Ruiz', '305-332-9593', '24'),
#  ('212', 'Matthew Hawkins', 'Games developer', 'Matthew_H33@xfinity.com', 'White, Hall and Morgan', '877-673-1620', '24'),
#  ('213', 'Ian Smith', 'Tour manager', 'Ian_Smith@aol.com', 'White, Wang and Cobb', '191-800-8457', '26'),
#  ('214', 'Tina Edwards', 'Engineer, drilling', 'Tina.Edwards80@gmail.com', 'Reilly and Sons', '894-827-8567', '38'),
#  ('215', 'Barbara Conner', 'Engineer, agricultural', 'BarbaraConner@zoho.com', 'Marks Inc', '570-820-1395', '39'),
#  ('216', 'Joseph Hunt', 'Orthoptist', 'Joseph_Hunt@protonmail.com', 'Larsen Inc', '907-282-2062', '26'),
#  ('217', 'Travis Johnson', 'Engineer, technical sales', 'Johnson_Travis@zoho.com', 'Mitchell, Paul and Cook', '223-504-1472', '24'),
#  ('218', 'Deborah Ayers', 'Fashion designer', 'DeborahAyers59@mail.com', 'Knight Inc', '645-555-9999', '30'),
#  ('219', 'Doris Oliver', 'Engineer, aeronautical', 'DorisOliver@gmail.com', 'Sandoval-Wade', '312-191-3186', '29'),
#  ('220', 'Carrie Smith', 'Engineer, aeronautical', 'Carrie.Smith@comcast.net', 'Lutz Group', '822-421-4292', '26'),
#  ('221', 'Olivia Wilson', 'Engineer, petroleum', 'Wilson.Olivia@mail.com', 'Miller Group', '982-134-3041', '40'),
#  ('222', 'Angela Morales', 'Engineer, biomedical', 'AngelaMorales@gmail.com', 'Perez-Woods', '485-445-2665', '33'),
#  ('223', 'Linda Dixon', 'Chemical engineer', 'Linda_Dixon@zoho.com', 'Boyd, Fisher and Gonzalez', '246-017-4207', '33'),
#  ('224', 'Kristina Chang', 'Engineer, control and instrumentation', 'Kristina_Chang@xfinity.com', 'Owens, Huber and Gonzalez', '101-704-5144', '36'),
#  ('225', 'Miss Jennifer Cunningham', 'Unemployed', 'Miss.C@xfinity.com', 'Edwards, Martin and Case', '112-683-0231', '16'),
#  ('226', 'Adam Ward', 'Police officer', 'Ward_Adam@yahoo.com', 'Soto-Hobbs', '877-739-8417', '28'),
#  ('227', 'Janet Rivers', 'Engineer, mining', 'Janet_R@yandex.com', 'Thompson, Valdez and Diaz', '804-428-7895', '22'),
#  ('228', 'Charles Smith', 'Engineer, energy', 'Smith_Charles@aol.com', 'Jacobs, Perez and Barrett', '848-661-2470', '32'),
#  ('229', 'Lori Massey', 'Computer games developer', 'Lori_M@xfinity.com', 'Berger and Sons', '855-010-1857', '36'),
#  ('230', 'Rhonda Moon', 'Chemical engineer', 'Rhonda_Moon@zoho.com', 'Kent LLC', '233-270-4887', '35'),
#  ('231', 'Shawn Smith', 'Police officer', 'Shawn.S@att.com', 'Roy, Peters and Jimenez', '494-035-3520', '27'),
#  ('232', 'Brian Ochoa', 'Unemployed', 'Brian.Ochoa40@att.com', 'Hughes, Hernandez and Thompson', '500-183-4583', '-1'),
#  ('233', 'Madison Hancock', 'Student', 'Madison.Hancock@verizon.com', 'Gordon Inc', '690-087-7498', '20'),
#  ('234', 'Dale Rogers', 'Unemployed', 'DRogers86@gmail.com', 'Allen-Tapia', '534-001-0222', '12'),
#  ('235', 'Earl Romero', 'Orthoptist', 'Earl.Romero@yandex.com', 'Wise Ltd', '607-022-0196', '34'),
#  ('236', 'Rachel Robinson', 'Risk analyst', 'Rachel.R@verizon.com', 'Meza Group', '608-275-4234', '32'),
#  ('237', 'Terry Williams', 'Orthoptist', 'Terry.W@zoho.com', 'Simpson, Ruiz and Frazier', '630-339-9195', '28'),
#  ('238', 'Michael Orr', 'Engineer, control and instrumentation', 'Orr_Michael@protonmail.com', 'Green-Burnett', '448-065-5550', '29'),
#  ('239', 'Stacy Flores', 'Engineer, control and instrumentation', 'SFlores66@verizon.com', 'Lowe, Blevins and Stephens', '925-289-7257', '35'),
#  ('240', 'Carrie Schmidt', 'Psychiatrist', 'Schmidt.Carrie66@verizon.com', 'Lucas Ltd', '497-555-4169', '30'),
#  ('241', 'Andrew Roberts', 'Doctor, general practice', 'Andrew_Roberts@zoho.com', 'Williams, Martinez and Davis', '733-741-4191', '40'),
#  ('242', 'Steven Hall', 'Barrister', 'Steven_H@mail.com', 'Johnson-Mcneil', '442-718-6339', '32'),
#  ('243', 'Jessica Walker', 'Unemployed', 'Walker.Jessica51@hotmail.com', 'Harris Group', '938-381-8501', '5'),
#  ('244', 'April Brown', 'Tour manager', 'April_Brown@protonmail.com', 'Davis, Garrison and Mason', '936-082-8659', '27'),
#  ('245', 'Tracy Hunter', 'Engineer, land', 'Tracy_H31@zoho.com', 'Stewart, Evans and George', '550-643-9769', '27'),
#  ('246', 'Brent Romero', 'Unemployed', 'Brent.R@aol.com', 'Yates, Chambers and Jones', '969-600-4397', '-5'),
#  ('247', 'Ryan Hubbard', 'Computer games developer', 'Ryan_H@protonmail.com', 'Long, Campbell and Thornton', '817-477-5736', '33'),
#  ('248', 'Christopher Shaffer', 'Computer games developer', 'Shaffer_Christopher@zoho.com', 'West and Sons', '439-740-9933', '26'),
#  ('249', 'Lacey Phillips', 'Unemployed', 'LaceyPhillips@att.com', 'Mcguire, Gonzales and Martin', '384-855-4277', '15'),
#  ('250', 'Steven Saunders', 'Chemical engineer', 'SSaunders@xfinity.com', 'Wright, Burke and Spencer', '867-727-5351', '23'),
#  ('251', 'Cheryl Kelly', 'Dentist', 'CKelly@xfinity.com', 'Taylor-Hubbard', '722-618-6237', '27'),
#  ('252', 'Carol Welch', 'Barista', 'Carol.Welch@outlook.com', 'Fletcher-Beasley', '958-522-6196', '36'),
#  ('253', 'Anthony Smith', 'Engineer, drilling', 'Anthony_S@comcast.net', 'Jones Ltd', '111-858-3157', '34'),
#  ('254', 'David Roach', 'Hotel manager', 'David_Roach93@mail.com', 'Alvarez Ltd', '284-024-0845', '31'),
#  ('255', 'Lori Parker', 'Graphic designer', 'Parker_Lori@yandex.com', 'Gonzalez, Buckley and Kramer', '227-835-8042', '55'),
#  ('256', 'Kevin Flores', 'Engineer, civil (contracting)', 'KevinFlores@aol.com', 'Holmes-Barton', '389-384-3519', '48'),
#  ('257', 'Troy Perkins', 'Chemical engineer', 'Perkins_Troy@comcast.net', 'Jordan-Perry', '792-625-0757', '24'),
#  ('258', 'John Peterson', 'Chemical engineer', 'John_P@verizon.com', 'Clayton, Miles and Walter', '112-580-8897', '29'),
#  ('259', 'Mia Jefferson', 'Engineer, civil (contracting)', 'Mia.Jefferson84@yandex.com', 'Carr PLC', '973-924-2778', '22'),
#  ('260', 'Lindsay Patel', 'Unemployed', 'LindsayPatel@comcast.net', 'Gonzalez, Smith and Hodge', '571-763-8224', '17'),
#  ('261', 'Chad Allison', 'Dentist', 'ChadAllison@outlook.com', 'Jensen, Boyle and Blake', '251-973-6803', '26'),
#  ('262', 'Matthew Bowen', 'Actor', 'Matthew_Bowen88@aol.com', 'Stevenson, Sanchez and Schultz', '771-327-0928', '28'),
#  ('263', 'Michael Ruiz', 'Engineer, technical sales', 'Ruiz.Michael60@aol.com', 'Lin, Davis and Carr', '259-820-2766', '40'),
#  ('264', 'Brian Burns', 'Psychiatrist', 'Brian.B@mail.com', 'Prince, Wilson and Brown', '600-723-1458', '33'),
#  ('265', 'Kristen Sloan', 'Unemployed', 'Kristen.Sloan@gmail.com', 'Friedman, Clayton and Williams', '267-025-5858', '15'),
#  ('266', 'Jacob Turner', 'Unemployed', 'Turner_Jacob27@verizon.com', 'Smith Ltd', '434-015-7809', '5'),
#  ('267', 'Julie Williams', 'Unemployed', 'Julie.W@hotmail.com', 'Sherman, Pratt and Riley', '911-870-5849', '12'),
#  ('268', 'Lisa Klein', 'Unemployed', 'Lisa.K@yahoo.com', 'Hall Group', '663-263-5713', '17'),
#  ('269', 'Emma Henderson', 'Unemployed', 'EmmaHenderson53@zoho.com', 'Ryan Group', '138-102-1115', '10'),
#  ('270', 'Mrs. Monique Nelson MD', 'Unemployed', 'Mrs..M@zoho.com', 'Fields, Berger and Gibson', '257-377-7618', '10'),
#  ('271', 'Chase Roberson', 'Chemical engineer', 'Chase.R@comcast.net', 'Jackson-Cooke', '644-544-1309', '32'),
#  ('272', 'Mandy Strickland', 'Engineer, broadcasting (operations)', 'Mandy.S@att.com', 'Guzman-Coleman', '324-135-3508', '27'),
#  ('273', 'Lisa Edwards', 'Unemployed', 'Edwards.Lisa@comcast.net', 'Kelly Inc', '908-636-0957', '16'),
#  ('274', 'Danielle Hanson', 'Unemployed', 'Hanson_Danielle@aol.com', 'Burns, Pearson and Rodriguez', '461-803-1752', '17'),
#  ('275', 'Caroline Maddox', 'Unemployed', 'Caroline_M@mail.com', 'Walker PLC', '309-407-0064', '11'),
#  ('276', 'Jonathan Garza', 'Barista', 'Jonathan.G99@zoho.com', 'Hancock, Jimenez and Williams', '334-544-4040', '29'),
#  ('277', 'Jessica Foster', 'Graphic designer', 'JessicaFoster@yahoo.com', 'Torres Group', '261-573-4701', '30'),
#  ('278', 'Linda Jimenez', 'Chemical engineer', 'Linda.Jimenez16@hotmail.com', 'Jones PLC', '300-557-9838', '27'),
#  ('279', 'Curtis Brown', 'Air traffic controller', 'Curtis_B@outlook.com', 'Donovan, Rios and Rivas', '205-615-0492', '39'),
#  ('280', 'Kathleen Bennett', 'Architect', 'Kathleen_Bennett60@xfinity.com', 'Obrien-Collins', '138-337-9140', '24'),
#  ('281', 'Thomas Diaz', 'Engineer, petroleum', 'TDiaz@mail.com', 'Brown Inc', '754-928-7648', '40'),
#  ('282', 'Christopher Hawkins', 'Engineer, land', 'ChristopherHawkins53@aol.com', 'Chambers PLC', '556-291-0916', '27'),
#  ('283', 'Kevin Martin', 'Unemployed', 'Kevin_M@aol.com', 'Hernandez Ltd', '965-808-1634', '13'),
#  ('284', 'Jeremiah Hart', 'Engineer, civil (consulting)', 'Jeremiah.Hart35@gmail.com', 'Henderson-Smith', '284-831-4233', '27'),
#  ('285', 'Stephen Crawford', 'Banker', 'Stephen.Crawford@gmail.com', 'Rogers PLC', '745-406-7706', '28'),
#  ('286', 'Amanda Crawford', 'Solicitor', 'Amanda_C@outlook.com', 'Wheeler, Carlson and Joseph', '849-890-4426', '27'),
#  ('287', 'Ashley Harris', 'Unemployed', 'Ashley.Harris@comcast.net', 'Mcdaniel-Ritter', '334-656-0219', '0'),
#  ('288', 'Anthony Wang', 'Engineer, site', 'AWang@yahoo.com', 'Pugh PLC', '694-221-5728', '38'),
#  ('289', 'William Scott', 'Unemployed', 'Scott.William@att.com', 'Lang, Davis and Watts', '212-417-0859', '16'),
#  ('290', 'Douglas Lee', 'Dentist', 'Douglas.L@zoho.com', 'Barnes PLC', '186-279-6375', '43'),
#  ('291', 'Michael Flowers', 'Engineer, water', 'Michael_Flowers@xfinity.com', 'Martinez-Burnett', '389-710-1605', '24'),
#  ('292', 'Cameron Harris', 'Engineer, communications', 'Cameron.Harris@zoho.com', 'Adams-Shaw', '880-703-7404', '25'),
#  ('293', 'Herbert Hall', 'Unemployed', 'Hall.Herbert@mail.com', 'Romero and Sons', '361-268-8207', '13'),
#  ('294', 'Julie Willis', 'Unemployed', 'Julie.W@aol.com', 'Banks-Watkins', '717-260-9176', '15'),
#  ('295', 'Tracy Roach', 'Student', 'Roach_Tracy73@xfinity.com', 'Martin and Sons', '447-284-1505', '21'),
#  ('296', 'Madison Glover', 'Unemployed', 'MadisonGlover@protonmail.com', 'Whitney and Sons', '364-220-7127', '16'),
#  ('297', 'Roger Maldonado', 'Chemical engineer', 'Roger.Maldonado82@att.com', 'Dyer-Thomas', '997-837-0818', '25'),
#  ('298', 'Diane Miles', 'Nurse', 'Diane_M@yahoo.com', 'Juarez, Kent and Williams', '469-254-7392', '30'),
#  ('299', 'Danielle Curry', 'Hotel manager', 'Danielle_C@yahoo.com', 'Young, Wade and Henderson', '545-759-5259', '40'),
#  ('300', 'Michelle Lawrence', 'Student', 'Michelle.Lawrence@gmail.com', 'Santana-Robinson', '735-206-8091', '19'),
#  ('301', 'Jennifer Jordan', 'Student', 'Jordan_Jennifer@mail.com', 'Brooks Inc', '392-854-5005', '19'),
#  ('302', 'Kathryn Stuart', 'Unemployed', 'Stuart_Kathryn45@verizon.com', 'Gonzalez, Harvey and Garcia', '410-137-8124', '17'),
#  ('303', 'Gabrielle Lopez', 'Student', 'Lopez_Gabrielle@comcast.net', 'Glenn and Sons', '871-908-7746', '18'),
#  ('304', 'Bryce Jenkins', 'Police officer', 'Bryce_J@yandex.com', 'Vasquez Group', '711-152-7102', '35'),
#  ('305', 'Shannon Summers', 'Chemical engineer', 'Summers.Shannon32@gmail.com', 'Stevenson, Silva and King', '812-301-1407', '25'),
#  ('306', 'David Powell', 'Surgeon', 'DavidPowell@comcast.net', 'Lambert-Moore', '671-003-9631', '27'),
#  ('307', 'Matthew Woodard', 'Student', 'Woodard.Matthew@aol.com', 'Moore, Hale and Robertson', '177-360-8083', '20'),
#  ('308', 'Jessica Mccarthy', 'Engineer, mining', 'Jessica_M68@comcast.net', 'Rivas-Nelson', '884-473-0523', '31'),
#  ('309', 'Felicia Lin', 'Unemployed', 'Felicia.L@att.com', 'Brown PLC', '386-243-3313', '12'),
#  ('310', 'Terry Thomas', 'Student', 'Terry.T@outlook.com', 'Patton-Harris', '673-138-1886', '20'),
#  ('311', 'Kelsey Lawrence', 'Student', 'Lawrence.Kelsey@xfinity.com', 'Bryant, Short and Velasquez', '885-064-9637', '18'),
#  ('312', 'Erica Brown', 'Unemployed', 'Erica_Brown@protonmail.com', 'Small-Cruz', '593-605-8798', '17'),
#  ('313', 'Stephen Thomas', 'Administrator', 'Stephen.Thomas@xfinity.com', 'Johnson-Coleman', '119-023-7127', '29'),
#  ('314', 'Bruce Ochoa', 'Risk analyst', 'Bruce_O22@mail.com', 'Stewart, Johnson and Torres', '441-759-8373', '25'),
#  ('315', 'Michelle Sullivan', 'Unemployed', 'Sullivan_Michelle89@yandex.com', 'Benson-Rodgers', '601-840-9851', '16'),
#  ('316', 'Dr. Jack Pennington', 'Barista', 'DPennington@xfinity.com', 'Doyle and Sons', '244-900-6542', '32'),
#  ('317', 'David Wagner', 'Chemical engineer', 'DWagner95@gmail.com', 'Thompson, Miller and Gill', '735-014-6863', '34'),
#  ('318', 'Darlene Miranda', 'Editor', 'Miranda_Darlene12@att.com', 'Price, Townsend and Chen', '151-966-7253', '47'),
#  ('319', 'Suzanne Heath', 'Unemployed', 'Heath_Suzanne30@comcast.net', 'Chang Inc', '291-668-1698', '9'),
#  ('320', 'George Jennings', 'Student', 'George_J44@mail.com', 'Gallagher, Taylor and George', '178-967-1316', '18'),
#  ('321', 'Jonathan Shepherd', 'Unemployed', 'Shepherd_Jonathan@outlook.com', 'Keller Inc', '500-782-7773', '16'),
#  ('322', 'Thomas Nguyen', 'Psychiatrist', 'Thomas_Nguyen84@mail.com', 'Jordan, James and Duran', '312-809-9925', '35'),
#  ('323', 'Michael Jones', 'Doctor, general practice', 'MichaelJones@yahoo.com', 'Buchanan-Stout', '517-409-7957', '35'),
#  ('324', 'Ruth Martinez', 'Computer games developer', 'Ruth_M@gmail.com', 'Kaufman, Ballard and King', '292-468-7945', '26'),
#  ('325', 'Diana Barrett', 'Banker', 'Diana_Barrett@gmail.com', 'Huffman-Ortiz', '396-328-9399', '25'),
#  ('326', 'Kimberly Delgado', 'Unemployed', 'Delgado.Kimberly@zoho.com', 'Maxwell Group', '625-182-6213', '1'),
#  ('327', 'Christy Smith', 'Engineer, broadcasting (operations)', 'Smith_Christy49@outlook.com', 'Sheppard Group', '357-355-9288', '26'),
#  ('328', 'Carlos Rogers', 'Student', 'Rogers_Carlos@yahoo.com', 'Williams, Richmond and Perez', '195-713-8486', '19'),
#  ('329', 'Michele Guerrero DDS', 'Chemical engineer', 'Michele_DDS@hotmail.com', 'Francis, Brown and Clark', '986-941-4368', '27'),
#  ('330', 'Jeffery Werner', 'Chemical engineer', 'Jeffery_Werner@aol.com', 'Deleon-Reed', '408-974-2032', '34'),
#  ('331', 'Susan Bass', 'Engineer, mining', 'SBass@att.com', 'Phillips PLC', '107-200-1833', '24'),
#  ('332', 'Corey Ferguson', 'Student', 'Ferguson_Corey@mail.com', 'Mcmahon and Sons', '958-447-5624', '20'),
#  ('333', 'Carla Marshall', 'Student', 'Carla_M@comcast.net', 'Snow and Sons', '983-683-8756', '19'),
#  ('334', 'Madison Powell', 'Unemployed', 'MadisonPowell89@gmail.com', 'Butler, Daniel and Gray', '670-490-2202', '-12'),
#  ('335', 'Emily Williams', 'Unemployed', 'Williams.Emily@yandex.com', 'Gonzalez-Martin', '720-016-5184', '17'),
#  ('336', 'Matthew Scott', 'Chemical engineer', 'MScott17@xfinity.com', 'Krause-Hernandez', '899-393-5732', '24'),
#  ('337', 'Kristen Higgins', 'Banker', 'Kristen.Higgins@gmail.com', 'Elliott-Washington', '823-395-4677', '31'),
#  ('338', 'Mark Contreras', 'Chemical engineer', 'Mark.C@yahoo.com', 'Santana, Moore and Murphy', '471-125-7177', '28'),
#  ('339', 'Teresa Lawson', 'Fashion designer', 'Teresa.Lawson@att.com', 'Wilson LLC', '499-232-2908', '29'),
#  ('340', 'Michael White', 'Architect', 'Michael.W@gmail.com', 'Dean-White', '699-488-6497', '34'),
#  ('341', 'Karen George', 'Unemployed', 'KarenGeorge57@aol.com', 'Delgado Inc', '122-033-5971', '16'),
#  ('342', 'Christopher Vang', 'Orthoptist', 'Vang.Christopher64@yandex.com', 'Hawkins-Garza', '448-707-5760', '33'),
#  ('343', 'Vernon Miller', 'Unemployed', 'Vernon.M@yahoo.com', 'House, Weaver and Holmes', '633-233-4127', '2'),
#  ('344', 'Christopher Nash', 'Games developer', 'Christopher.N91@att.com', 'Burton-Contreras', '327-134-2258', '23'),
#  ('345', 'Elaine Scott', 'Risk analyst', 'Scott.Elaine94@att.com', 'Martin and Sons', '143-964-9261', '35'),
#  ('346', 'Kelly Smith', 'Unemployed', 'Kelly_S11@hotmail.com', 'Adams-Williams', '730-190-3182', '11'),
#  ('347', 'Damon Cooper', 'Engineer, technical sales', 'DamonCooper32@att.com', 'Horton, Evans and Martinez', '997-085-9100', '25'),
#  ('348', 'Elizabeth Ryan', 'Engineer, materials', 'ERyan@mail.com', 'Mendez-Ayers', '367-248-6308', '22'),
#  ('349', 'Kim Miles', 'Unemployed', 'KimMiles89@comcast.net', 'Clark-Rivera', '904-467-9892', '16'),
#  ('350', 'Mackenzie Riggs', 'Solicitor', 'Mackenzie_R56@yahoo.com', 'Velez Inc', '314-761-2711', '31'),
#  ('351', 'George Woods', 'Unemployed', 'George.W@yandex.com', 'Clayton, Wheeler and Ellis', '717-243-0154', '16'),
#  ('352', 'Kimberly Dominguez', 'Student', 'Dominguez.Kimberly@yandex.com', 'Hernandez, Miller and White', '357-962-9059', '21'),
#  ('353', 'Nicholas Marquez', 'Unemployed', 'Marquez_Nicholas@verizon.com', 'Thornton-Osborn', '784-831-9470', '14'),
#  ('354', 'Nicholas Jones', 'Barrister', 'NicholasJones@yahoo.com', 'Morgan Group', '541-153-3698', '27'),
#  ('355', 'Richard Mendoza', 'Student', 'Richard_Mendoza92@yandex.com', 'Arnold, Haney and Dennis', '703-163-5822', '19'),
#  ('356', 'Eric Hubbard', 'Unemployed', 'Eric.H@outlook.com', 'Fitzgerald, Miller and Gomez', '747-503-5185', '14'),
#  ('357', 'Lori Smith', 'Counsellor', 'Lori_Smith@hotmail.com', 'Wright, Kelly and Brooks', '267-894-2653', '39'),
#  ('358', 'Katherine Fitzgerald', 'Student', 'Katherine_F@yahoo.com', 'Medina-Tran', '746-622-1278', '21'),
#  ('359', 'Victoria Scott', 'IT consultant', 'Scott_Victoria@outlook.com', 'Sanchez-Bullock', '471-608-7801', '35'),
#  ('360', 'Kim Harrell', 'Engineer, petroleum', 'Kim_H@verizon.com', 'Elliott-Dunn', '871-433-1609', '31'),
#  ('361', 'Mallory Oconnor', 'Fashion designer', 'Oconnor_Mallory@gmail.com', 'Joseph LLC', '796-259-2559', '31'),
#  ('362', 'Austin Livingston', 'Student', 'Austin_L43@gmail.com', 'Suarez, Bailey and Jenkins', '960-566-8314', '20'),
#  ('363', 'Cameron Gordon', 'Air traffic controller', 'Gordon_Cameron@att.com', 'Hill LLC', '339-420-7744', '24'),
#  ('364', 'Matthew Crawford', 'Student', 'MCrawford@hotmail.com', 'Smith LLC', '237-107-1004', '21'),
#  ('365', 'Erin Mccullough', 'Engineer, technical sales', 'Mccullough.Erin@yandex.com', 'Gardner, Scott and Swanson', '462-689-9047', '30'),
#  ('366', 'Anthony Green', 'Engineer, aeronautical', 'Green.Anthony69@comcast.net', 'Juarez and Sons', '308-439-7251', '42'),
#  ('367', 'Thomas Gordon', 'Architect', 'Thomas_Gordon@hotmail.com', 'Rodgers Inc', '998-078-4110', '22'),
#  ('368', 'Ryan Santana', 'Unemployed', 'Santana.Ryan95@comcast.net', 'Johnson, Velazquez and Miller', '291-127-8585', '16'),
#  ('369', 'Roger Beasley', 'Unemployed', 'Beasley.Roger@yandex.com', 'Moore Inc', '216-755-4959', '14'),
#  ('370', 'Gregory Perkins MD', 'Risk analyst', 'GregoryMD@verizon.com', 'West, Howard and Wheeler', '478-229-3631', '32'),
#  ('371', 'David Simmons', 'Chemical engineer', 'DSimmons@hotmail.com', 'Walters, Kelley and Moore', '477-506-0977', '36'),
#  ('372', 'Jacob Perry', 'Orthoptist', 'JPerry@mail.com', 'Mcdaniel Ltd', '169-345-5634', '27'),
#  ('373', 'Jordan Smith', 'Student', 'Smith_Jordan@aol.com', 'Fields-Jacobs', '566-074-7836', '18'),
#  ('374', 'Paul Rowe', 'Solicitor', 'Paul_R@yahoo.com', 'Armstrong-Murphy', '245-480-9516', '29'),
#  ('375', 'Lynn Lawrence', 'Unemployed', 'Lynn.Lawrence@outlook.com', 'Vincent-Salazar', '755-840-6502', '13'),
#  ('376', 'Joshua Potts', 'Unemployed', 'Joshua.P70@verizon.com', 'Ruiz-Briggs', '688-908-8390', '15'),
#  ('377', 'Joanna Armstrong', 'Student', 'Joanna.A@yahoo.com', 'Gibson, Rogers and Ross', '129-610-7304', '19'),
#  ('378', 'Michael Jones', 'Unemployed', 'Michael_Jones@yandex.com', 'Melendez PLC', '490-206-7393', '15'),
#  ('379', 'Michael Savage', 'Chemical engineer', 'Savage.Michael@gmail.com', 'Weber-Nelson', '942-190-8460', '29'),
#  ('380', 'Christina Bowman', 'Unemployed', 'CBowman69@hotmail.com', 'Freeman, Hayden and Conner', '140-420-2744', '17'),
#  ('381', 'Robert Flores', 'Student', 'Robert_Flores@yahoo.com', 'Smith PLC', '192-462-9886', '20'),
#  ('382', 'James Krause', 'Unemployed', 'James_K@outlook.com', 'Conway, Moss and Peters', '594-796-2645', '14'),
#  ('383', 'Briana Avila', 'Unemployed', 'Briana_Avila@mail.com', 'Griffin, Sanchez and Thompson', '241-297-0330', '11'),
#  ('384', 'Amy Decker', 'Unemployed', 'Amy_D70@yahoo.com', 'Lopez-King', '915-620-3420', '13'),
#  ('385', 'Laura Brown', 'Engineer, control and instrumentation', 'Laura.B@aol.com', 'Ochoa, Davis and Tran', '364-362-5275', '41'),
#  ('386', 'Peter Rivas', 'Engineer, site', 'Peter_Rivas@protonmail.com', 'Martinez-Porter', '553-516-9157', '24'),
#  ('387', 'Samuel Dean', 'Chemical engineer', 'Dean_Samuel@aol.com', 'Ellis, Warren and Nelson', '370-478-5752', '41'),
#  ('388', 'Michael Davis', 'Student', 'MichaelDavis@xfinity.com', 'Padilla, Ward and Collier', '602-822-1587', '21'),
#  ('389', 'Omar Martinez', 'Editor', 'Omar_M68@att.com', 'Williams, Wright and Anderson', '748-209-0243', '25'),
#  ('390', 'Christian Johnson', 'Chemical engineer', 'Johnson.Christian@yahoo.com', 'Murphy-Morris', '767-430-6144', '25'),
#  ('391', 'Kelly Chen', 'Unemployed', 'KellyChen55@outlook.com', 'Barajas-Powell', '285-740-1532', '15'),
#  ('392', 'Zachary Wilson', 'Hotel manager', 'Zachary.W32@hotmail.com', 'Scott-Padilla', '789-099-9220', '32'),
#  ('393', 'Dawn Montgomery', 'Nurse', 'Dawn.M@att.com', 'Hill-Banks', '140-030-6082', '32'),
#  ('394', 'Stephanie Meyer', 'Engineer, materials', 'Meyer_Stephanie@hotmail.com', 'Parker and Sons', '339-106-4157', '38'),
#  ('395', 'Bonnie Flores', 'Unemployed', 'BFlores86@yandex.com', 'Cooper PLC', '364-426-4451', '14'),
#  ('396', 'Nathaniel Herman', 'Unemployed', 'Herman_Nathaniel@comcast.net', 'Doyle Group', '814-832-7624', '17'),
#  ('397', 'Vanessa Anderson', 'Administrator', 'Anderson.Vanessa@zoho.com', 'Gutierrez, Cunningham and Hayes', '709-449-1445', '29'),
#  ('398', 'Richard Butler', 'Engineer, broadcasting (operations)', 'Richard_B@gmail.com', 'Jackson, Kennedy and Wright', '717-387-0108', '41'),
#  ('399', 'Dana Johnson', 'Actuary', 'Dana.Johnson@xfinity.com', 'Oliver-Ramirez', '238-875-4410', '33'),
#  ('400', 'Tony Lee', 'Administrator', 'Lee.Tony29@protonmail.com', 'Tucker, West and Williams', '954-283-9997', '25'),
#  ('401', 'Michael Wallace', 'Engineer, automotive', 'MWallace66@xfinity.com', 'Sanchez-Miller', '408-218-5336', '33'),
#  ('402', 'Beth Rose', 'Chemical engineer', 'Beth.R@outlook.com', 'Ray-Lyons', '777-096-6834', '45'),
#  ('403', 'Dana Hernandez', 'Student', 'Hernandez.Dana@verizon.com', 'Long and Sons', '943-097-4778', '18'),
#  ('404', 'Ryan Moyer', 'Engineer, manufacturing', 'Moyer.Ryan@comcast.net', 'Robinson Inc', '162-159-0813', '33'),
#  ('405', 'Larry Lopez', 'Engineer, energy', 'Lopez_Larry73@hotmail.com', 'Montgomery LLC', '978-023-2917', '24'),
#  ('406', 'Jill Huang', 'Student', 'Jill.Huang@att.com', 'Cervantes, Rhodes and Guerrero', '730-807-3862', '19'),
#  ('407', 'Christina Drake', 'Student', 'Christina_Drake31@zoho.com', 'Richards, Castro and Garcia', '732-289-8048', '18'),
#  ('408', 'Chad Gregory', 'Games developer', 'ChadGregory@outlook.com', 'Gordon, Stevenson and Arnold', '898-960-3744', '22'),
#  ('409', 'Jason Hudson', 'Tour manager', 'Hudson_Jason@yandex.com', 'Munoz, Cruz and Keller', '680-335-4729', '32'),
#  ('410', 'Christopher Davis', 'Student', 'Christopher_D50@outlook.com', 'Clarke, Skinner and Maynard', '626-964-5286', '20'),
#  ('411', 'Tammy Clark', 'Hotel manager', 'Clark.Tammy@yandex.com', 'White, Roman and Barnes', '601-721-9893', '26'),
#  ('412', 'Russell Mendoza', 'Student', 'Russell.Mendoza@verizon.com', 'Anderson-Case', '911-686-7894', '21'),
#  ('413', 'Tracy Bowman', 'Chemical engineer', 'Bowman_Tracy34@gmail.com', 'Myers, Carpenter and Santana', '989-274-6235', '32'),
#  ('414', 'Kelly Taylor', 'Unemployed', 'Kelly_T@comcast.net', 'Moore, Long and Arellano', '409-049-8911', '11'),
#  ('415', 'Rhonda Dodson', 'Games developer', 'RhondaDodson@comcast.net', 'Bailey LLC', '383-554-2937', '32'),
#  ('416', 'Taylor Parker', 'Chemical engineer', 'TParker60@hotmail.com', 'Mcdonald-Johnson', '109-812-0619', '32'),
#  ('417', 'Christy Adkins', 'Unemployed', 'Christy.A@protonmail.com', 'Rivera-Patterson', '239-576-7387', '1'),
#  ('418', 'Natalie Jones', 'Surgeon', 'NJones73@xfinity.com', 'Campos-Thompson', '319-250-2014', '39'),
#  ('419', 'Paul Medina', 'Unemployed', 'Medina_Paul@mail.com', 'James-Carpenter', '453-824-3513', '16'),
# ...
#  ('860', 'William Thompson', 'Unemployed', 'Thompson.William@comcast.net', 'Kirby-Morris', '399-155-7818', '16'),
#  ('861', 'Ryan Carlson', 'Unemployed', 'Ryan.C@zoho.com', 'Johnson Group', '684-775-5875', '17'),
#  ('862', 'John Lopez', 'Administrator', 'John_Lopez@aol.com', 'Heath-Simon', '603-743-8665', '43'),
#  ('863', 'Mrs. Jennifer Mclaughlin', 'Student', 'Mclaughlin_Mrs.@xfinity.com', 'Tapia Ltd', '781-980-6268', '18'),
#  ('864', 'Jerry Baker', 'Chemical engineer', 'Jerry_Baker@xfinity.com', 'Bryan, Sullivan and Miller', '427-158-6258', '36'),
#  ('865', 'Anthony Coleman', 'IT consultant', 'Anthony.C71@comcast.net', 'Lopez LLC', '487-726-9968', '35'),
#  ('866', 'William Rice', 'Police officer', 'Rice.William@xfinity.com', 'Ramirez, Williams and Ortiz', '190-600-2618', '23'),
#  ('867', 'Rachel Ray', 'Counsellor', 'Rachel.Ray@comcast.net', 'Rice, Thomas and Flores', '178-339-6014', '23'),
#  ('868', 'Heather Steele', 'Engineer, biomedical', 'HSteele@gmail.com', 'Lopez PLC', '820-727-4753', '33'),
#  ('869', 'Courtney Harris', 'Chemical engineer', 'Harris_Courtney@xfinity.com', 'Yang and Sons', '766-135-3259', '23'),
#  ('870', 'Jennifer Mcdaniel', 'Student', 'JenniferMcdaniel@comcast.net', 'Austin-Davis', '730-836-2560', '21'),
#  ('871', 'Riley Garrison', 'Student', 'RileyGarrison@protonmail.com', 'Molina, White and Burnett', '747-061-2813', '19'),
#  ('872', 'Sherry Gonzalez', 'Librarian, public', 'Sherry.G@gmail.com', 'Jones PLC', '121-969-6772', '25'),
#  ('873', 'Christie Garcia', 'Engineer, energy', 'Garcia_Christie@mail.com', 'Moore Inc', '876-076-2231', '23'),
#  ('874', 'Maureen Smith', 'Orthoptist', 'Maureen_S@protonmail.com', 'Walker Group', '498-037-5886', '29'),
#  ('875', 'Michele Perry', 'Student', 'Michele_Perry@xfinity.com', 'Faulkner-Vang', '813-535-6545', '20'),
#  ('876', 'Garrett Wise', 'Student', 'Garrett.Wise39@yahoo.com', 'Hammond, Romero and Johnson', '891-196-3248', '19'),
#  ('877', 'Kenneth Carter', 'Engineer, broadcasting (operations)', 'Kenneth_C@mail.com', 'Williams Inc', '559-100-0681', '35'),
#  ('878', 'Stacy Barnett', 'Unemployed', 'SBarnett@yandex.com', 'Fox-Rosales', '469-061-9497', '-2'),
#  ('879', 'Angela Morales', 'Engineer, maintenance (IT)', 'Morales.Angela12@yahoo.com', 'Romero, Waters and Thompson', '235-064-5885', '26'),
#  ('880', 'Amy Vargas', 'Psychiatrist', 'Amy.Vargas20@att.com', 'Martin, Medina and Kennedy', '949-342-2536', '36'),
#  ('881', 'Alexandra Allen', 'Unemployed', 'Alexandra_Allen51@outlook.com', 'Romero and Sons', '897-327-1503', '10'),
#  ('882', 'Christopher Perkins', 'Unemployed', 'Christopher_P@aol.com', 'Hudson-Lowe', '927-078-6867', '16'),
#  ('883', 'Zachary Anderson', 'Unemployed', 'Zachary.Anderson@xfinity.com', 'Vargas, Dyer and Wise', '491-986-9395', '15'),
#  ('884', 'Lindsay Munoz', 'Unemployed', 'LMunoz@protonmail.com', 'Taylor-Jones', '686-870-5465', '11'),
#  ('885', 'Wendy Freeman', 'Student', 'WFreeman@comcast.net', 'Webb-Gillespie', '751-424-1735', '20'),
#  ('886', 'Jacob Roberts', 'Unemployed', 'JacobRoberts45@yahoo.com', 'Lutz-Henderson', '260-245-2473', '16'),
#  ('887', 'Amber Koch', 'Engineer, petroleum', 'Amber_K80@zoho.com', 'Griffin-Johnson', '504-221-5403', '28'),
#  ('888', 'Laura Harvey', 'Unemployed', 'Laura.H@hotmail.com', 'Lopez, Burgess and Murphy', '316-906-4266', '14'),
#  ('889', 'Leah Coleman', 'Chemical engineer', 'Coleman_Leah@yandex.com', 'Ashley-Williams', '768-607-5347', '28'),
#  ('890', 'Michael Finley', 'Barista', 'Finley_Michael@zoho.com', 'Ramirez Inc', '606-754-5260', '31'),
#  ('891', 'Michael Ramirez', 'Engineer, agricultural', 'MichaelRamirez44@outlook.com', 'Martinez, Pena and Lee', '541-760-4255', '31'),
#  ('892', 'Kristina Ho', 'Engineer, water', 'Ho.Kristina@xfinity.com', 'Andrews, Baker and White', '643-981-0457', '28'),
#  ('893', 'Wendy Thornton', 'Chemical engineer', 'Thornton_Wendy@aol.com', 'Cox-Smith', '180-475-7205', '40'),
#  ('894', 'Todd Odonnell', 'Student', 'ToddOdonnell@outlook.com', 'Graham Group', '765-313-1724', '18'),
#  ('895', 'Derek Martinez', 'Editor', 'Derek.Martinez55@yahoo.com', 'Bullock-Green', '707-794-5848', '49'),
#  ('896', 'Debra Wilkins', 'Engineer, technical sales', 'Debra.W@yahoo.com', 'Obrien LLC', '833-156-9727', '27'),
#  ('897', 'Thomas Lewis', 'Engineer, maintenance', 'Thomas_L@zoho.com', 'Valencia, Grimes and Parker', '460-395-6590', '34'),
#  ('898', 'Philip Turner', 'Engineer, civil (consulting)', 'PTurner60@comcast.net', 'Montgomery LLC', '667-117-7396', '34'),
#  ('899', 'Catherine Miller', 'Student', 'Catherine_Miller25@gmail.com', 'Miller-Jones', '206-153-4549', '18'),
#  ('900', 'Aaron Gutierrez', 'IT consultant', 'Gutierrez.Aaron@protonmail.com', 'Crawford-Gross', '188-915-8192', '39'),
#  ('901', 'Taylor Bradley', 'Engineer, energy', 'Taylor_B51@protonmail.com', 'Cowan and Sons', '725-800-3185', '43'),
#  ('902', 'Carrie Clark', 'Unemployed', 'Carrie_C@att.com', 'Mcdonald and Sons', '196-815-0063', '12'),
#  ('903', 'Matthew Ramirez', 'Unemployed', 'Matthew_R@protonmail.com', 'Torres and Sons', '286-171-1248', '4'),
#  ('904', 'James Bush', 'Student', 'Bush.James37@xfinity.com', 'Neal LLC', '103-899-9072', '21'),
#  ('905', 'Timothy Bowen', 'Administrator', 'Timothy.Bowen@mail.com', 'Mclean-Jones', '752-137-7664', '24'),
#  ('906', 'Donna Cruz', 'Student', 'Cruz.Donna@att.com', 'Bridges Inc', '619-726-0890', '21'),
#  ('907', 'Nicholas Gill', 'Librarian, public', 'Nicholas.Gill@gmail.com', 'Phillips-Valdez', '399-732-5338', '40'),
#  ('908', 'Shane Morrison', 'Engineer, biomedical', 'Shane.M@gmail.com', 'Gonzales, Andrade and Frank', '133-020-6751', '36'),
#  ('909', 'Ian Davis', 'Student', 'Ian.Davis@zoho.com', 'Turner, Lloyd and Bond', '204-935-2110', '20'),
#  ('910', 'Briana Garcia', 'Engineer, manufacturing', 'Briana.G@protonmail.com', 'Porter Group', '858-813-4780', '35'),
#  ('911', 'Karen Stewart', 'Chemical engineer', 'KStewart@outlook.com', 'Brown-Castaneda', '323-974-4389', '32'),
#  ('912', 'Sara Proctor', 'Unemployed', 'SProctor@yandex.com', 'Henry, Turner and Holmes', '361-123-7554', '9'),
#  ('913', 'Andrea Lamb', 'Engineer, control and instrumentation', 'AndreaLamb@protonmail.com', 'Foster-Conway', '577-769-8566', '23'),
#  ('914', 'Donald Rodriguez', 'Unemployed', 'Donald.R@zoho.com', 'Cook, Vance and Wilkins', '219-501-3369', '6'),
#  ('915', 'Richard Figueroa', 'Actuary', 'Richard.F54@yandex.com', 'Mccormick PLC', '945-976-8141', '42'),
#  ('916', 'Alexandra Rowe', 'Graphic designer', 'ARowe@verizon.com', 'Eaton-Arroyo', '660-194-2230', '27'),
#  ('917', 'Robert Rodgers', 'Fashion designer', 'Robert.Rodgers@comcast.net', 'Kim, Finley and Wallace', '129-190-8592', '34'),
#  ('918', 'Alison Vaughan', 'Engineer, water', 'Vaughan.Alison91@att.com', 'Adams PLC', '470-488-8589', '36'),
#  ('919', 'Scott Hanson', 'Editor', 'ScottHanson@gmail.com', 'Marquez-Collins', '886-873-6567', '34'),
#  ('920', 'Nancy Schroeder', 'Chemical engineer', 'Nancy.Schroeder@yahoo.com', 'Mitchell and Sons', '983-273-0575', '35'),
#  ('921', 'Brandy Ferguson', 'Engineer, manufacturing', 'Ferguson_Brandy78@att.com', 'Yoder Group', '763-041-2531', '32'),
#  ('922', 'Barbara Williams', 'Engineer, manufacturing', 'Williams.Barbara@zoho.com', 'Hall-Hall', '402-659-7626', '39'),
#  ('923', 'Kathy Watson', 'Tour manager', 'Kathy_Watson@att.com', 'Cardenas-Ball', '234-144-2036', '43'),
#  ('924', 'Nathan Hansen', 'Student', 'Hansen_Nathan87@outlook.com', 'Stewart-Elliott', '895-905-9465', '18'),
#  ('925', 'Krista Christensen', 'Actuary', 'Christensen.Krista@mail.com', 'Mathews, Mckee and Rios', '572-790-1818', '27'),
#  ('926', 'Lydia Thompson', 'Engineer, structural', 'Lydia.Thompson@mail.com', 'Yu-Anderson', '815-031-9763', '32'),
#  ('927', 'Ms. Melanie Smith', 'Engineer, automotive', 'Ms._Smith@hotmail.com', 'Jenkins, Nelson and Fleming', '618-491-3484', '29'),
#  ('928', 'Brett Henderson', 'Engineer, energy', 'Brett.H@outlook.com', 'Myers-Brandt', '445-164-5445', '27'),
#  ('929', 'Joshua Smith', 'Student', 'Joshua.S@att.com', 'Marshall Inc', '726-007-9291', '18'),
#  ('930', 'Lisa White', 'Chemical engineer', 'Lisa.W@xfinity.com', 'Smith, Glass and Walker', '348-102-4821', '23'),
#  ('931', 'Joshua Hayes', 'Tour manager', 'Joshua.Hayes@yahoo.com', 'Alvarez-Boyer', '193-649-3923', '40'),
#  ('932', 'Kristen Hinton', 'Tour manager', 'KristenHinton71@att.com', 'Mcguire LLC', '112-874-7219', '30'),
#  ('933', 'David Brown', 'Unemployed', 'Brown_David@att.com', 'Anderson-Brooks', '845-581-9708', '10'),
#  ('934', 'Whitney Wright', 'Administrator', 'Whitney.Wright@xfinity.com', 'Torres Ltd', '680-100-0209', '27'),
#  ('935', 'Claire Bryant', 'Architect', 'Claire.B@protonmail.com', 'Rogers Ltd', '577-937-4818', '47'),
#  ('936', 'Christopher Daugherty', 'Chemical engineer', 'ChristopherDaugherty@comcast.net', 'Sullivan Ltd', '472-855-6677', '27'),
#  ('937', 'Beth Garza', 'Chemical engineer', 'Beth.Garza@mail.com', 'Munoz-Garcia', '835-142-2053', '29'),
#  ('938', 'Rachel Gordon', 'Barista', 'Gordon.Rachel87@yandex.com', 'Norman, Wilson and Johnson', '715-651-6097', '43'),
#  ('939', 'Katrina Daniels', 'Engineer, broadcasting (operations)', 'KDaniels48@outlook.com', 'Garza Group', '241-749-0142', '27'),
#  ('940', 'Jessica Young', 'Hotel manager', 'JYoung45@gmail.com', 'Thompson, Miller and Small', '865-735-4207', '25'),
#  ('941', 'Anthony Clark', 'Engineer, building services', 'Clark.Anthony@xfinity.com', 'Knight Group', '949-764-3265', '33'),
#  ('942', 'Douglas Blevins', 'Unemployed', 'Douglas.B83@verizon.com', 'Herman Group', '809-512-9527', '15'),
#  ('943', 'Jeffrey Coleman', 'Engineer, mining', 'Jeffrey_Coleman@gmail.com', 'Griffin-Moreno', '477-129-5920', '29'),
#  ('944', 'Kayla Allison', 'Chemical engineer', 'KAllison@outlook.com', 'Meyers, Lloyd and Rollins', '695-078-5606', '25'),
#  ('945', 'Ashley Roberts', 'Unemployed', 'Ashley_R@yahoo.com', 'Zimmerman-Page', '987-926-5695', '13'),
#  ('946', 'Jordan Patrick', 'Chemical engineer', 'Jordan.Patrick71@mail.com', 'Ellis, Bowman and Dominguez', '504-781-0151', '25'),
#  ('947', 'Fred Weber MD', 'Engineer, manufacturing systems', 'Fred_MD@att.com', 'Rogers-Walter', '469-941-2645', '48'),
#  ('948', 'Roy Holland', 'Engineer, mining', 'Roy.H@hotmail.com', 'Serrano Ltd', '771-516-2375', '25'),
#  ('949', 'Susan Johnson', 'Engineer, communications', 'SusanJohnson@outlook.com', 'Sellers-Thompson', '556-053-8391', '32'),
#  ('950', 'Jennifer Collins', 'Nurse', 'Jennifer.Collins@comcast.net', 'Friedman Group', '278-596-8018', '22'),
#  ('951', 'Desiree Young', 'Chemical engineer', 'Desiree_Y@yahoo.com', 'Wilson-Trevino', '324-701-8708', '33'),
#  ('952', 'Yolanda White', 'Chemical engineer', 'Yolanda_White57@zoho.com', 'Jones-Summers', '706-755-6105', '25'),
#  ('953', 'Barbara Charles', 'Chemical engineer', 'Barbara.C@yahoo.com', 'Rodriguez LLC', '664-995-8822', '31'),
#  ('954', 'Christopher Jackson Jr.', 'Engineer, civil (consulting)', 'CJr.@aol.com', 'Simon, Powell and Mccarty', '878-531-1493', '26'),
#  ('955', 'Maria Elliott', 'Student', 'Elliott.Maria@mail.com', 'Brennan and Sons', '613-591-1776', '19'),
#  ('956', 'Tina Owens', 'Student', 'Tina.Owens@gmail.com', 'Marshall, Pierce and Ford', '397-730-5210', '18'),
#  ('957', 'Joseph Wyatt', 'Student', 'Wyatt.Joseph@mail.com', 'Bowers, Farley and Wright', '733-098-9704', '18'),
#  ('958', 'Adam Leonard', 'Unemployed', 'Adam.L@att.com', 'Weber, Ray and Knapp', '389-176-8899', '11'),
#  ('959', 'Misty Johnson', 'Student', 'Johnson.Misty@aol.com', 'Alexander-Ochoa', '953-593-9545', '20'),
#  ('960', 'Jessica Schwartz', 'Unemployed', 'JSchwartz@verizon.com', 'Park, Gordon and Edwards', '658-342-9897', '5'),
#  ('961', 'Donald Cordova', 'Student', 'Donald.Cordova@zoho.com', 'Lin-Miller', '507-272-7011', '18'),
#  ('962', 'Anthony Hughes', 'Student', 'AHughes19@yahoo.com', 'Martinez, Romero and Quinn', '124-531-2998', '20'),
#  ('963', 'Heather Wilcox', 'Chemical engineer', 'HeatherWilcox@protonmail.com', 'Terry, Cabrera and Jones', '223-816-5792', '24'),
#  ('964', 'Erin Grimes', 'Student', 'Erin_G@protonmail.com', 'Oconnell-Jackson', '191-605-0982', '18'),
#  ('965', 'Shannon Gomez', 'Engineer, mining', 'Shannon_Gomez@gmail.com', 'Smith, Parker and Hernandez', '150-983-2296', '48'),
#  ('966', 'William Garcia', 'Engineer, broadcasting (operations)', 'Garcia.William@protonmail.com', 'Arias, Johnson and Harris', '483-863-4105', '29'),
#  ('967', 'Stephanie Burns', 'Librarian, public', 'Stephanie.B@yandex.com', 'Castaneda and Sons', '359-704-6018', '30'),
#  ('968', 'Tyler Morgan', 'Unemployed', 'TylerMorgan@comcast.net', 'Pace, Gutierrez and Vega', '144-124-7519', '17'),
#  ('969', 'Scott Alvarez', 'Engineer, electronics', 'Scott_A93@mail.com', 'Wilson, Harris and Collins', '832-594-9516', '23'),
#  ('970', 'Patrick Berger', 'Unemployed', 'Berger_Patrick@aol.com', 'Ward, Stafford and Lee', '383-482-2003', '11'),
#  ('971', 'Kelly Young', 'Student', 'Kelly.Y@xfinity.com', 'Brown-Hawkins', '200-343-1793', '20'),
#  ('972', 'Jennifer Howard', 'Unemployed', 'Jennifer.Howard@yandex.com', 'Singleton LLC', '769-056-7735', '16'),
#  ('973', 'William Jackson', 'Engineer, communications', 'William.Jackson@comcast.net', 'Bonilla, Williams and Berger', '939-210-6856', '35'),
#  ('974', 'Ryan Bennett', 'Engineer, production', 'Bennett_Ryan@verizon.com', 'Harper, Black and Mendez', '570-573-4846', '35'),
#  ('975', 'Joshua Woods', 'Engineer, maintenance', 'JoshuaWoods@comcast.net', 'Lee Ltd', '363-778-5888', '34'),
#  ('976', 'Gregory Guerrero', 'Unemployed', 'GregoryGuerrero@att.com', 'Thomas-Winters', '564-293-6901', '15'),
#  ('977', 'Bobby Aguirre', 'Unemployed', 'BobbyAguirre@att.com', 'Mora and Sons', '724-150-5399', '11'),
#  ('978', 'Laura Cunningham', 'Counsellor', 'LauraCunningham@hotmail.com', 'Williams and Sons', '189-261-6626', '29'),
#  ('979', 'Jesus Moss', 'Unemployed', 'Moss.Jesus@outlook.com', 'Byrd-Leonard', '708-564-5613', '15'),
#  ('980', 'Michael Johnson', 'Engineer, electrical', 'Johnson.Michael@gmail.com', 'Young Ltd', '766-636-6725', '30'),
#  ('981', 'John Whitney', 'Chemical engineer', 'Whitney.John@att.com', 'Perkins Inc', '527-631-7990', '26'),
#  ('982', 'Dr. Lisa Neal', 'Engineer, land', 'Dr..Neal11@xfinity.com', 'Cox-Richardson', '377-862-1286', '22'),
#  ('983', 'Ashley Rodriguez', 'Student', 'Ashley.R@gmail.com', 'Serrano Group', '437-923-7332', '18'),
#  ('984', 'Craig Parsons', 'Banker', 'Craig.Parsons@att.com', 'Shannon-Vang', '639-288-0923', '33'),
#  ('985', 'Alan Mitchell', 'Engineer, electrical', 'Mitchell.Alan77@hotmail.com', 'Wagner Inc', '454-752-1489', '46'),
#  ('986', 'Zachary Stevenson', 'Unemployed', 'ZStevenson@protonmail.com', 'Smith-Gibson', '380-732-7540', '5'),
#  ('987', 'Meagan Nelson', 'Barista', 'MNelson@outlook.com', 'Nash Group', '452-073-6301', '28'),
#  ('988', 'Patricia Reese', 'Unemployed', 'Patricia.Reese@att.com', 'Mcmahon, Ochoa and Guerra', '156-119-8122', '16'),
#  ('989', 'Nicole Smith', 'Unemployed', 'Nicole_Smith84@outlook.com', 'Cross PLC', '286-981-1376', '12'),
#  ('990', 'Thomas Hill', 'Chemical engineer', 'Hill_Thomas@gmail.com', 'Nguyen, Elliott and Nelson', '826-267-1331', '31'),
#  ('991', 'Allen Robertson', 'Chemical engineer', 'ARobertson@zoho.com', 'Wells, Caldwell and Peters', '632-516-3293', '26'),
#  ('992', 'Tracy Perez', 'Unemployed', 'Perez_Tracy@aol.com', 'Hines-White', '398-597-9570', '14'),
#  ('993', 'Susan Murray', 'Engineer, energy', 'SMurray@aol.com', 'Lane-Rose', '478-936-2789', '29'),
#  ('994', 'Ruben Steele', 'Orthoptist', 'Ruben.Steele@att.com', 'Rodriguez-Matthews', '383-441-3281', '30'),
#  ('995', 'Ashley Young', 'Student', 'Ashley_Y@xfinity.com', 'Esparza-Johnson', '751-654-6719', '19'),
#  ('996', 'Mr. Steven Smith', 'Engineer, structural', 'Mr..Smith@zoho.com', 'Hensley-Odom', '279-898-4565', '26'),
#  ('997', 'Mark Smith', 'Engineer, control and instrumentation', 'Mark_S@yahoo.com', 'Fisher LLC', '563-382-1868', '29'),
#  ('998', 'Jeffrey Carrillo', 'Unemployed', 'JeffreyCarrillo@yahoo.com', 'Morgan LLC', '223-784-2416', '15'),
#  ('999', 'Karen Barber', 'Doctor, general practice', 'Karen.Barber20@yandex.com', 'Nelson, Joseph and Fowler', '512-703-6189', '24')]

# %%
# %%sql
# select * from call limit 0
# Out:
#  * sqlite:///call_center_database.db
# Done.
# []

# %% [markdown]
# ### Exercise 1
#
# Calculate the average age across all customers. The result of your query should have only one column (called `average_age`) and one row (the actual average numeric age).

# %%
def age_customers():
    """
    Calculate the mean age of customers.
    
    Arguments: None
    
    Output:
    query: The SQL query. A string (please refer to the example below)
    
    Example:
    In this function, you only need to write the query inside quotes.
    For instance, if you wanted to see the first 5 rows of the `call` table, this
    should be your code:
    
    query = "SELECT * FROM call LIMIT 5"
    
    If you need to write your query in more than one line (ie. with line breaks),
    you can use triple quotes: https://www.tutorialspoint.com/triple-quotes-in-python
    
    """

    
    return "select AVG(Age) as average_age from customer"

# %% [markdown]
# ### Exercise 2
#
# Calculate the average age of customers who actually made a purchase as a result of a call. The result of your query should have only one column (called `average_age_purchased`) and one row (the actual average numeric age).
#
# **Hint:** Join the `customer` and `call` tables, keep only the calls that resulted in a sale, and then compute the average age. It is true that a single customer may appear several times in the result (which would mean they were contacted more than once and made a purchase more than once). Ignore this and simply average the ages across all sales.

# %%
def age_customers_purchased():
    """
    Calculate the mean age of customers who made purchases.
    
    Arguments: None
    
    Output:
    query: The SQL query. A string (please refer to the example below)
    
    Example:
    In this function, you only need to write the query inside quotes.
    For instance, if you wanted to see the first 5 rows of the `call` table, this
    should be your code:
    
    query = "SELECT * FROM call LIMIT 5"
    
    If you need to write your query in more than one line (ie. with line breaks),
    you can use triple quotes: https://www.tutorialspoint.com/triple-quotes-in-python
    
    """
    
    return """
            select AVG(Age) as average_age_purchased from
            (select MAX(Age) as Age, call.CustomerID from Customer 
            inner join call on call.CustomerID = customer.customerID
            group by call.customerID)
    """

# %% [markdown]
# ### Exercise 3
#
# Determine the 6 companies which are most highly represented among the customers. Your result should have two columns (`Company` and `number_customers`) and one row.
#
# **Hint:** Count the number of customers who have links to each company (group by company), sort the result in descending order, and finally retrieve only the first 6 rows.

# %%
def most_frequent_companies():
    """
    Find which 6 companies are the most frequent among customers.
    
    Arguments: None
    
    Output:
    query: The SQL query. A string (please refer to the example below)
    
    Example:
    In this function, you only need to write the query inside quotes.
    For instance, if you wanted to see the first 5 rows of the `call` table, this
    should be your code:
    
    query = "SELECT * FROM call LIMIT 5"
    
    If you need to write your query in more than one line (ie. with line breaks),
    you can use triple quotes: https://www.tutorialspoint.com/triple-quotes-in-python
    
    """
    

    
    return """
            select Company, COUNT(customerID) as number_customers from customer
            group by Company
            order by COUNT(customerID) desc
            limit 6 
    """

# %% [markdown]
# ### Exercise 4
#
# Retrieve all the customers that have Gmail email accounts. Your result must have one column (`Email`) and 79 rows (the 79 customers who have Gmail accounts).

# %%
def gmail_accounts():
    """
    Retrieve all the customers who have Gmail accounts.
    
    Arguments: None
    
    Output:
    query: The SQL query. A string (please refer to the example below)
    
    Example:
    In this function, you only need to write the query inside quotes.
    For instance, if you wanted to see the first 5 rows of the `call` table, this
    should be your code:
    
    query = "SELECT * FROM call LIMIT 5"
    
    If you need to write your query in more than one line (ie. with line breaks),
    you can use triple quotes: https://www.tutorialspoint.com/triple-quotes-in-python
    
    """
    
    
    
    return """
            select Email from customer
            where Email like '%gmail%'
    """

# %% [markdown]
# ## Testing Cells
#
# Run the below cells to check your answers. Make sure you run your solution cells first before running the cells below, otherwise you will get a `NameError` when checking your answers.

# %%
# Ex 1
import pandas as pd
ava = pd.read_sql(age_customers(), con="sqlite:///call_center_database.db")
assert ava.columns == ["average_age"], "Ex. 1 - Your result should only have one column, and it should be named 'average_age'!"
assert len(ava) == 1, "Ex. 1 - Your result should have only one row!"
assert round(ava["average_age"][0],3) == round(24.435, 3), "Ex. 1 - Please check the aggregation function you used. Did you calculate the average age of all customers?"
print("Exercise 1 seems correct!")
# Out:
# Exercise 1 seems correct!

# %%
# Ex 2
import pandas as pd
avap = pd.read_sql(age_customers_purchased(), con="sqlite:///call_center_database.db")
assert avap.columns == ["average_age_purchased"], "Ex. 2 - Your result should only have one column, and it should be named 'average_age_purchased'!"
assert len(avap) == 1, "Ex. 2 - Your result should have only one row!"
assert round(avap["average_age_purchased"][0],3) == round(24.708253358925145, 3), "Ex. 2 - Please check the aggregation function you used. Did you calculate the average age of all customers who made a purchase?"
print("Exercise 2 seems correct!")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-43-ad4563526aad> in <module>
#       4 assert avap.columns == ["average_age_purchased"], "Ex. 2 - Your result should only have one column, and it should be named 'average_age_purchased'!"
#       5 assert len(avap) == 1, "Ex. 2 - Your result should have only one row!"
# ----> 6 assert round(avap["average_age_purchased"][0],3) == round(24.708253358925145, 3), "Ex. 2 - Please check the aggregation function you used. Did you calculate the average age of all customers who made a purchase?"
#       7 print("Exercise 2 seems correct!")
#
# AssertionError: Ex. 2 - Please check the aggregation function you used. Did you calculate the average age of all customers who made a purchase?

# %%
# Ex 3
import pandas as pd
mcc = pd.read_sql(most_frequent_companies(), con="sqlite:///call_center_database.db")
assert set(mcc.columns) == set(["Company", "number_customers"]), "Ex. 3 - Your result should have two columns, named 'Customer' and 'number_customers'!"
assert len(mcc) == 6, "Ex. 3 - Your result should have 6 rows! Remember to group by company and limit your results to only 6 companies!"
assert set(["Romero and Sons","Mitchell and Sons","Miller Group","Kelly Inc","Jones PLC","Hernandez and Sons"]) == set(mcc["Company"].to_list()), "Ex. 3 - Your result does not include all the companies in the top 6! Did you sort the results in descending order?"
print("Exercise 3 seems correct!")
# Out:
# Exercise 3 seems correct!

# %%
# Ex 4
import pandas as pd
gm = pd.read_sql(gmail_accounts(), con="sqlite:///call_center_database.db")
assert set(gm.columns) == set(["Email"]), "Ex. 4 - Your result should have only one column, 'Email'!"
assert len(gm) == 79, "Ex. 4 - Your result should have 79 rows! Remember to filter your results using WHERE and the LIKE operator!"
assert gm["Email"].str.count("gmail").sum() == 79, "Ex. 4 - Your result contains some customers whose Email is not Gmail!"
print("Exercise 4 seems correct!")
# Out:
# Exercise 4 seems correct!
